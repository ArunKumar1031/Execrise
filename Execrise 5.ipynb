# %%
#Step 1. Import the necessary libraries
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
#Step 2. Import the dataset
#Step 3. Assign it to a variable called iris
#Step 4. Create columns for the dataset
# 1. sepal_length (in cm)
# 2. sepal_width (in cm)
# 3. petal_length (in cm)
# 4. petal_width (in cm)
# 5. class
iris=pd.read_csv('iris.data' , names = ["sepal_length (in cm)","sepal_width (in cm)","petal_length (in cm)","petal_width (in cm)","class"])

# %%
iris
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      petal_width (in cm)           class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# ...

# %%
#Step 5. Is there any missing value in the dataframe?
iris.isnull().sum()
# Out:
# sepal_length (in cm)    0
# sepal_width (in cm)     0
# petal_length (in cm)    0
# petal_width (in cm)     0
# class                   0
# dtype: int64

# %%
#Step 6. Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN
for i in range(20):
    iris['petal_length (in cm)'][i+10]=np.nan

# %%
iris
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      petal_width (in cm)           class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# ...

# %%
#Step 7. Good, now lets substitute the NaN values to 1.0
for i in range(20):
    iris['petal_length (in cm)'][i+10]=1

# %%
iris
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      petal_width (in cm)           class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# ...

# %%
#Step 8. Now let's delete the column cl
del iris["class"]

# %%
iris
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      petal_width (in cm)
# 0                    0.2
# 1                    0.2
# 2                    0.2
# 3                    0.2
# ...

# %%
#Step 9. Set the first 3 rows as NaN
iris[0:3]=np.nan

# %%
iris
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     NaN                  NaN                   NaN
# 1                     NaN                  NaN                   NaN
# 2                     NaN                  NaN                   NaN
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      petal_width (in cm)
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    0.2
# ...

# %%
#Step 10. Delete the rows that have NaN
iris1=iris.dropna(how='all')

# %%
iris1
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      petal_width (in cm)
# 3                    0.2
# 4                    0.2
# 5                    0.4
# 6                    0.3
# ...

# %%
#Step 11. Reset the index so it begins with 0 again
iris2=iris1.reset_index()

# %%
iris2
# Out:
#      index  sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0        3                   4.6                  3.1                   1.5
# 1        4                   5.0                  3.6                   1.4
# 2        5                   5.4                  3.9                   1.7
# 3        6                   4.6                  3.4                   1.4
# 4        7                   5.0                  3.4                   1.5
# ..     ...                   ...                  ...                   ...
# 142    145                   6.7                  3.0                   5.2
# 143    146                   6.3                  2.5                   5.0
# 144    147                   6.5                  3.0                   5.2
# 145    148                   6.2                  3.4                   5.4
# 146    149                   5.9                  3.0                   5.1
#
#      petal_width (in cm)
# 0                    0.2
# ...

# %%
del iris2['index']

# %%
iris2
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     4.6                  3.1                   1.5
# 1                     5.0                  3.6                   1.4
# 2                     5.4                  3.9                   1.7
# 3                     4.6                  3.4                   1.4
# 4                     5.0                  3.4                   1.5
# ..                    ...                  ...                   ...
# 142                   6.7                  3.0                   5.2
# 143                   6.3                  2.5                   5.0
# 144                   6.5                  3.0                   5.2
# 145                   6.2                  3.4                   5.4
# 146                   5.9                  3.0                   5.1
#
#      petal_width (in cm)
# 0                    0.2
# 1                    0.2
# 2                    0.4
# 3                    0.3
# ...
